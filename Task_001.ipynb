# %% [markdown]
# **Дана функция f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30**
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
import math
from sympy import *
from sympy.plotting import plot as plt
init_printing()

x = Symbol('x')
fx = 18 * x ** 2 + 10 * x - 30
fx
# Out:
#     2
# 18⋅x  + 10⋅x - 30

# %% [markdown]
# **1. Определить корни**

# %%
x1, x2 = solve(fx)
x1 = round(x1.evalf(), 2)
x2 = round(x2.evalf(), 2)

x1_st = str(x1)
x2_st = str(x2)
if x1_st.find('I') or x2_st.find('I'):
    print('Действительных корней нет.\n Решение в комплексных переменных:')
    print(f'первый корень = {x1}\n второй корень = {x2}')
else:
    print(f'первый корень = {x1}\n второй корень = {x2}')

# %% [markdown]
# **2. Найти интервалы, на которых функция возрастает**

# %%
interval_1=solve(diff(fx)>0)
print(f'Функция {fx} возрастает на интервале(ах): {interval_1}')
interval_1
# Out:
# Функция 18*x**2 + 10*x - 30 возрастает на интервале(ах): (-5/18 < x) & (x < oo)
# -5/18 < x ∧ x < ∞

# %% [markdown]
# **3. Найти интервалы, на которых функция убывает**

# %%
interval_2=solve(diff(fx)<0)
print(f'Функция {fx} убывает на интервале(ах): {interval_2}')
interval_2
# Out:
# Функция 18*x**2 + 10*x - 30 убывает на интервале(ах): (-oo < x) & (x < -5/18)
# -∞ < x ∧ x < -5/18

# %% [markdown]
# **4. Построить график**

# %%
p = plt(fx)
